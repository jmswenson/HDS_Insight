# %%
import processing
# functions of interest from processing: load_and_process_data puts a bunch of fcs files into one dataframe,
## load_fcs_files_from_dropbox returns a list of pandas dataframes (each dataframe is one fcs file)
import os

import pandas as pd
import numpy as np
import glob
# Out:
# //anaconda/envs/py2-env/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# //anaconda/envs/py2-env/lib/python2.7/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# Make sure that labelled cell popultion csvs are in the same directory as the entire well, otherwise the below name matching doesn't work. These are example file names: 'screen_525_cell_plate_1_well_c03.csv', 'screen_525_cell_plate_1_well_c03_cluster_blast.csv', 'screen_525_cell_plate_1_well_c03_cluster_healthy.csv'.

# %%
#screen_path = '/Users/tswenson/Dropbox (COMPANY)/screens/screen_525/cell_plate_1/merged/';
#screen_path = '/Users/tswenson/Dropbox (COMPANY)/screens/screen_509/cell_plate_1/screen_509_cell_plate_1_labeled_merged/';
#screen_path = '/Users/tswenson/Dropbox (COMPANY)/screens/screen_404/cell_plate_1/training_set/';
screen_path = '/Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/';
#screen_path = '/Users/tswenson/Documents/Joels/Health_Data_Science/COMPANY_consulting_project/datasets/screen_357_labelled_merged/Well_';
data = processing.load_fcs_files_from_dropbox(\
            location=screen_path, \
            filename_template='Well*.fcs', screens=None, cell_plates=None, wells=None, verbose=True)
# Out:
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C03.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C04.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C05.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C06.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C07.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C08.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C09.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C10.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C11.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C12.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C13.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C14.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C15.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C16.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C17.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C18.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C19.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C20.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C21.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_C22.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D03.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D04.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D05.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D06.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D07.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D08.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D09.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D10.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D11.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D12.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D13.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D14.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D15.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D16.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D17.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D18.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D19.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D20.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D21.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_D22.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E03.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E04.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E05.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E06.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E07.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E08.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E09.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E10.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E11.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E12.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E13.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E14.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E15.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E16.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E17.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E18.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E19.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E19_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E20.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E21.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E21_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_E22.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F03.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F03_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F04.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F05.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F05_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F06.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F07.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F07_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F08.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F09.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F09_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F10.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F11.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F11_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F12.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F13.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F13_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F14.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F15.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F15_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F16.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F17.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F17_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F18.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F19.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F20.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F21.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F21_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_F22.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G03.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G03_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G04.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G05.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G05_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G06.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G07.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G07_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G08.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G09.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G09_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G10.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G11.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G11_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G12.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G13.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G13_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G14.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G15.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G15_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G16.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G17.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G17_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G18.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G19.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G19_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G20.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G21.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G21_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_G22.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H03.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H03_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H04.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H05.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H05_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H06.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H07.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H07_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H08.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H09.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H09_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H10.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H11.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H11_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H12.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H13.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H13_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H14.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H15.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H15_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H16.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H17.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H17_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H18.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H19.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H19_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H20.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H21.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H21_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_H22.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I03.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I03_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I04.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I05.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I05_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I06.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I07.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I07_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I08.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I09.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I09_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I10.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I11.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I11_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I12.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I13.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I13_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I14.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I15.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I15_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I16.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I17.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I17_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I18.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I19.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I19_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I20.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I21.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I21_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_I22.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J03.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J03_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J04.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J05.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J05_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J06.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J07.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J07_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J08.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J09.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J09_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J10.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J11.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J11_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J12.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J13.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J13_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J14.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J15.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J15_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J16.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J17.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J17_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J18.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J19.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J19_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J20.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J21.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J21_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_J22.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K03.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K03_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K04.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K05.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K05_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K06.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K07.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K07_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K08.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K09.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K09_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K10.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K11.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K11_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K12.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K13.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K13_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K14.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K15.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K15_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K16.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K17.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K18.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K19.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K19_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K20.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K21.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K21_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_K22.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L03.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L03_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L04.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L05.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L05_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L06.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L07.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L07_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L08.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L09.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L09_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L10.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L11.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L11_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L12.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L13.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L13_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L14.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L15.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L15_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L16.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L17.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L17_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L18.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L19.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L19_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L20.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L21.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L21_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_L22.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M03.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M03_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M04.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M05.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M05_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M06.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M07.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M07_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M08.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M09.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M09_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M10.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M11.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M12.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M13.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M13_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M14.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M15.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M15_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M16.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M17.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M17_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M18.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M19.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M19_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M20.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M21.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M21_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_M22.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N03.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N03_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N04.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N05.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N05_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N06.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N07.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N07_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N08.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N09.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N09_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N10.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N11.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N11_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N12.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N13.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N13_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N14.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N15.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N16.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N16_cluster_blast.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N17.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N18.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N19.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N20.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N21.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N22.fcs
# Loading: /Users/tswenson/Dropbox (COMPANY)/screens/screen_357/cell_plate_1/screen_357_cell_plate_1_labeled_merged/Well_N22_cluster_blast.fcs

# %%
#type(data) # list
len(data)
# Out:
# 327

# %%
print(type(data[0]))
print(data[0].head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      FSC-H     SSC-H  CD34 H : FITC H  CD14 H : PE H  BL3-H  BL4-H  \
# 0  8461803  16756139             3406           3241   5111   3970
# 1    65242   1266425              488             96    681   1501
# 2   337209   1223704                0             83      0    939
# 3  1007446   1181087                0            603   1307    300
# 4  5306675   1140815              803           1753   2403   2362
#
#    CD66b H : CD3 H : PE-Cy7 H  Kit H : APC H  RL2-H  DAPI H  \
# 0                       12753           5064  16662    4499
# 1                        2046           1237   2335     157
# 2                        2372            603   3364      53
# 3                        3877            630   1516     105
# 4                        2878           2262   3477    1276
#
#                     ...                     VL2-A  VL3-A  VL4-A   VL5-A  \
# 0                   ...                    183895      0      0  139455
# 1                   ...                         0      0      0       0
# 2                   ...                      1684   1084      0       0
# 3                   ...                         0      0      0       0
# 4                   ...                      6573   2304      0       0
#
#    CD38 A : BV785 A  Width  Time                                  screen  \
# 0           1050445   5415  7744  screen_357_cell_plate_1_labeled_merged
# 1                 0     26  7744  screen_357_cell_plate_1_labeled_merged
# 2                 0     40  7744  screen_357_cell_plate_1_labeled_merged
# 3                 0     45  7744  screen_357_cell_plate_1_labeled_merged
# 4                 0    228  7744  screen_357_cell_plate_1_labeled_merged
#
#        well                              cell_plate
# 0  well_c03  screen_357_cell_plate_1_labeled_merged
# 1  well_c03  screen_357_cell_plate_1_labeled_merged
# 2  well_c03  screen_357_cell_plate_1_labeled_merged
# 3  well_c03  screen_357_cell_plate_1_labeled_merged
# 4  well_c03  screen_357_cell_plate_1_labeled_merged
#
# [5 rows x 35 columns]

# %%
cwd = os.getcwd()

# %%
print(cwd)
# Out:
# /Users/tswenson/Documents/Joels/Health_Data_Science/COMPANY_consulting_project/python_code/automated-flow-alpha/code

# %% [markdown]
# ### Make a new directory for the csv files

# %%
dataset_dir = '/Users/tswenson/Documents/Joels/Health_Data_Science/COMPANY_consulting_project/datasets/'
exp_name = screen_path.strip().split('/')[-2]

# %%
print(exp_name)
# Out:
# screen_357_cell_plate_1_labeled_merged

# %%
directory = dataset_dir + exp_name + "_csvs"
if not os.path.exists(directory):
    print("Making directory called" + directory)
    os.makedirs(directory)
else:
    print("Direct with the following name already exists: " + directory + '/')
# Out:
# Making directory called/Users/tswenson/Documents/Joels/Health_Data_Science/COMPANY_consulting_project/datasets/screen_357_cell_plate_1_labeled_merged_csvs

# %%
data[0].head()
# Out:
#      FSC-H     SSC-H  CD34 H : FITC H  CD14 H : PE H  BL3-H  BL4-H  \
# 0  8461803  16756139             3406           3241   5111   3970
# 1    65242   1266425              488             96    681   1501
# 2   337209   1223704                0             83      0    939
# 3  1007446   1181087                0            603   1307    300
# 4  5306675   1140815              803           1753   2403   2362
#
#    CD66b H : CD3 H : PE-Cy7 H  Kit H : APC H  RL2-H  DAPI H  \
# 0                       12753           5064  16662    4499
# 1                        2046           1237   2335     157
# 2                        2372            603   3364      53
# 3                        3877            630   1516     105
# 4                        2878           2262   3477    1276
#
#                     ...                     VL2-A  VL3-A  VL4-A   VL5-A  \
# 0                   ...                    183895      0      0  139455
# 1                   ...                         0      0      0       0
# 2                   ...                      1684   1084      0       0
# 3                   ...                         0      0      0       0
# 4                   ...                      6573   2304      0       0
#
#    CD38 A : BV785 A  Width  Time                                  screen  \
# 0           1050445   5415  7744  screen_357_cell_plate_1_labeled_merged
# 1                 0     26  7744  screen_357_cell_plate_1_labeled_merged
# 2                 0     40  7744  screen_357_cell_plate_1_labeled_merged
# 3                 0     45  7744  screen_357_cell_plate_1_labeled_merged
# 4                 0    228  7744  screen_357_cell_plate_1_labeled_merged
#
#        well                              cell_plate
# 0  well_c03  screen_357_cell_plate_1_labeled_merged
# 1  well_c03  screen_357_cell_plate_1_labeled_merged
# 2  well_c03  screen_357_cell_plate_1_labeled_merged
# 3  well_c03  screen_357_cell_plate_1_labeled_merged
# 4  well_c03  screen_357_cell_plate_1_labeled_merged
#
# [5 rows x 35 columns]

# %%
idx = 0; file_name = [];
for fcs_df in data:
    file_name.append(fcs_df.iloc[0]['screen'] + '_' + fcs_df.iloc[0]['cell_plate']\
                     + '_' + fcs_df.iloc[0]['well'] + ".csv")
    print(file_name[idx])
    print(idx)
    fcs_df.to_csv(directory + '/' + file_name[idx])
    idx += 1
# Out:
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c03.csv
# 0
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c04.csv
# 1
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c05.csv
# 2
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c06.csv
# 3
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c07.csv
# 4
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c08.csv
# 5
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c09.csv
# 6
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c10.csv
# 7
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c11.csv
# 8
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c12.csv
# 9
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c13.csv
# 10
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c14.csv
# 11
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c15.csv
# 12
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c16.csv
# 13
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c17.csv
# 14
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c18.csv
# 15
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c19.csv
# 16
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c20.csv
# 17
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c21.csv
# 18
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_c22.csv
# 19
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d03.csv
# 20
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d04.csv
# 21
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d05.csv
# 22
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d06.csv
# 23
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d07.csv
# 24
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d08.csv
# 25
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d09.csv
# 26
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d10.csv
# 27
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d11.csv
# 28
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d12.csv
# 29
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d13.csv
# 30
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d14.csv
# 31
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d15.csv
# 32
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d16.csv
# 33
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d17.csv
# 34
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d18.csv
# 35
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d19.csv
# 36
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d20.csv
# 37
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d21.csv
# 38
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_d22.csv
# 39
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e03.csv
# 40
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e04.csv
# 41
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e05.csv
# 42
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e06.csv
# 43
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e07.csv
# 44
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e08.csv
# 45
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e09.csv
# 46
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e10.csv
# 47
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e11.csv
# 48
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e12.csv
# 49
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e13.csv
# 50
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e14.csv
# 51
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e15.csv
# 52
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e16.csv
# 53
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e17.csv
# 54
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e18.csv
# 55
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e19.csv
# 56
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e19_cluster_blast.csv
# 57
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e20.csv
# 58
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e21.csv
# 59
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e21_cluster_blast.csv
# 60
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e22.csv
# 61
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f03.csv
# 62
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f03_cluster_blast.csv
# 63
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f04.csv
# 64
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f05.csv
# 65
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f05_cluster_blast.csv
# 66
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f06.csv
# 67
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f07.csv
# 68
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f07_cluster_blast.csv
# 69
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f08.csv
# 70
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f09.csv
# 71
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f09_cluster_blast.csv
# 72
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f10.csv
# 73
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f11.csv
# 74
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f11_cluster_blast.csv
# 75
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f12.csv
# 76
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f13.csv
# 77
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f13_cluster_blast.csv
# 78
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f14.csv
# 79
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f15.csv
# 80
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f15_cluster_blast.csv
# 81
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f16.csv
# 82
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f17.csv
# 83
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f17_cluster_blast.csv
# 84
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f18.csv
# 85
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f19.csv
# 86
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f20.csv
# 87
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f21.csv
# 88
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f21_cluster_blast.csv
# 89
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f22.csv
# 90
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g03.csv
# 91
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g03_cluster_blast.csv
# 92
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g04.csv
# 93
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g05.csv
# 94
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g05_cluster_blast.csv
# 95
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g06.csv
# 96
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g07.csv
# 97
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g07_cluster_blast.csv
# 98
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g08.csv
# 99
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g09.csv
# 100
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g09_cluster_blast.csv
# 101
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g10.csv
# 102
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g11.csv
# 103
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g11_cluster_blast.csv
# 104
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g12.csv
# 105
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g13.csv
# 106
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g13_cluster_blast.csv
# 107
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g14.csv
# 108
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g15.csv
# 109
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g15_cluster_blast.csv
# 110
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g16.csv
# 111
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g17.csv
# 112
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g17_cluster_blast.csv
# 113
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g18.csv
# 114
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g19.csv
# 115
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g19_cluster_blast.csv
# 116
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g20.csv
# 117
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g21.csv
# 118
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g21_cluster_blast.csv
# 119
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g22.csv
# 120
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h03.csv
# 121
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h03_cluster_blast.csv
# 122
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h04.csv
# 123
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h05.csv
# 124
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h05_cluster_blast.csv
# 125
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h06.csv
# 126
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h07.csv
# 127
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h07_cluster_blast.csv
# 128
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h08.csv
# 129
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h09.csv
# 130
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h09_cluster_blast.csv
# 131
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h10.csv
# 132
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h11.csv
# 133
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h11_cluster_blast.csv
# 134
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h12.csv
# 135
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h13.csv
# 136
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h13_cluster_blast.csv
# 137
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h14.csv
# 138
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h15.csv
# 139
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h15_cluster_blast.csv
# 140
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h16.csv
# 141
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h17.csv
# 142
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h17_cluster_blast.csv
# 143
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h18.csv
# 144
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h19.csv
# 145
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h19_cluster_blast.csv
# 146
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h20.csv
# 147
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h21.csv
# 148
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h21_cluster_blast.csv
# 149
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h22.csv
# 150
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i03.csv
# 151
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i03_cluster_blast.csv
# 152
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i04.csv
# 153
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i05.csv
# 154
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i05_cluster_blast.csv
# 155
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i06.csv
# 156
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i07.csv
# 157
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i07_cluster_blast.csv
# 158
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i08.csv
# 159
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i09.csv
# 160
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i09_cluster_blast.csv
# 161
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i10.csv
# 162
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i11.csv
# 163
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i11_cluster_blast.csv
# 164
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i12.csv
# 165
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i13.csv
# 166
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i13_cluster_blast.csv
# 167
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i14.csv
# 168
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i15.csv
# 169
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i15_cluster_blast.csv
# 170
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i16.csv
# 171
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i17.csv
# 172
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i17_cluster_blast.csv
# 173
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i18.csv
# 174
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i19.csv
# 175
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i19_cluster_blast.csv
# 176
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i20.csv
# 177
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i21.csv
# 178
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i21_cluster_blast.csv
# 179
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i22.csv
# 180
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j03.csv
# 181
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j03_cluster_blast.csv
# 182
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j04.csv
# 183
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j05.csv
# 184
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j05_cluster_blast.csv
# 185
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j06.csv
# 186
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j07.csv
# 187
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j07_cluster_blast.csv
# 188
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j08.csv
# 189
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j09.csv
# 190
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j09_cluster_blast.csv
# 191
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j10.csv
# 192
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j11.csv
# 193
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j11_cluster_blast.csv
# 194
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j12.csv
# 195
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j13.csv
# 196
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j13_cluster_blast.csv
# 197
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j14.csv
# 198
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j15.csv
# 199
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j15_cluster_blast.csv
# 200
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j16.csv
# 201
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j17.csv
# 202
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j17_cluster_blast.csv
# 203
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j18.csv
# 204
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j19.csv
# 205
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j19_cluster_blast.csv
# 206
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j20.csv
# 207
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j21.csv
# 208
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j21_cluster_blast.csv
# 209
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j22.csv
# 210
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k03.csv
# 211
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k03_cluster_blast.csv
# 212
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k04.csv
# 213
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k05.csv
# 214
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k05_cluster_blast.csv
# 215
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k06.csv
# 216
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k07.csv
# 217
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k07_cluster_blast.csv
# 218
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k08.csv
# 219
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k09.csv
# 220
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k09_cluster_blast.csv
# 221
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k10.csv
# 222
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k11.csv
# 223
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k11_cluster_blast.csv
# 224
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k12.csv
# 225
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k13.csv
# 226
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k13_cluster_blast.csv
# 227
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k14.csv
# 228
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k15.csv
# 229
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k15_cluster_blast.csv
# 230
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k16.csv
# 231
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k17.csv
# 232
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k18.csv
# 233
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k19.csv
# 234
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k19_cluster_blast.csv
# 235
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k20.csv
# 236
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k21.csv
# 237
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k21_cluster_blast.csv
# 238
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k22.csv
# 239
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l03.csv
# 240
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l03_cluster_blast.csv
# 241
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l04.csv
# 242
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l05.csv
# 243
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l05_cluster_blast.csv
# 244
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l06.csv
# 245
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l07.csv
# 246
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l07_cluster_blast.csv
# 247
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l08.csv
# 248
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l09.csv
# 249
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l09_cluster_blast.csv
# 250
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l10.csv
# 251
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l11.csv
# 252
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l11_cluster_blast.csv
# 253
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l12.csv
# 254
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l13.csv
# 255
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l13_cluster_blast.csv
# 256
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l14.csv
# 257
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l15.csv
# 258
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l15_cluster_blast.csv
# 259
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l16.csv
# 260
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l17.csv
# 261
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l17_cluster_blast.csv
# 262
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l18.csv
# 263
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l19.csv
# 264
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l19_cluster_blast.csv
# 265
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l20.csv
# 266
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l21.csv
# 267
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l21_cluster_blast.csv
# 268
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l22.csv
# 269
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m03.csv
# 270
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m03_cluster_blast.csv
# 271
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m04.csv
# 272
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m05.csv
# 273
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m05_cluster_blast.csv
# 274
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m06.csv
# 275
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m07.csv
# 276
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m07_cluster_blast.csv
# 277
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m08.csv
# 278
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m09.csv
# 279
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m09_cluster_blast.csv
# 280
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m10.csv
# 281
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m11.csv
# 282
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m12.csv
# 283
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m13.csv
# 284
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m13_cluster_blast.csv
# 285
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m14.csv
# 286
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m15.csv
# 287
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m15_cluster_blast.csv
# 288
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m16.csv
# 289
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m17.csv
# 290
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m17_cluster_blast.csv
# 291
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m18.csv
# 292
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m19.csv
# 293
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m19_cluster_blast.csv
# 294
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m20.csv
# 295
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m21.csv
# 296
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m21_cluster_blast.csv
# 297
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m22.csv
# 298
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n03.csv
# 299
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n03_cluster_blast.csv
# 300
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n04.csv
# 301
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n05.csv
# 302
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n05_cluster_blast.csv
# 303
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n06.csv
# 304
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n07.csv
# 305
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n07_cluster_blast.csv
# 306
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n08.csv
# 307
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n09.csv
# 308
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n09_cluster_blast.csv
# 309
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n10.csv
# 310
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n11.csv
# 311
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n11_cluster_blast.csv
# 312
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n12.csv
# 313
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n13.csv
# 314
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n13_cluster_blast.csv
# 315
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n14.csv
# 316
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n15.csv
# 317
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n16.csv
# 318
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n16_cluster_blast.csv
# 319
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n17.csv
# 320
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n18.csv
# 321
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n19.csv
# 322
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n20.csv
# 323
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n21.csv
# 324
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n22.csv
# 325
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n22_cluster_blast.csv
# 326

# %%
# data[0], data[1] and data[2] are parent, blast, normal (respectively). Ditto for 11, 12, 13
# Note that the column orders are different between the parent and children and that the parent has a "width" column
## while the children don't

print(list(data[3].columns.values))
print(list(data[4].columns.values))
print(list(data[5].columns.values))
# Out:
# [u'FSC-H', u'SSC-H', u'CD34 H : FITC H', u'Kit H : PE H', u'BL3-H', u'BL4-H', u'CD163 H : PE-Cy7 H', u'CD3 H : CD66b H : APC H', u'RL2-H', u'DAPI H', u'VL2-H', u'VL3-H', u'VL4-H', u'VL5-H', u'CD38 H : BV785 H', u'FSC-A', u'SSC-A', u'CD34 A : FITC A', u'Kit A : PE A', u'BL3-A', u'BL4-A', u'CD163 A : PE-Cy7 A', u'CD3 A : CD66b A : APC A', u'RL2-A', u'DAPI A', u'VL2-A', u'VL3-A', u'VL4-A', u'VL5-A', u'CD38 A : BV785 A', u'Width', u'Time', 'screen', 'well', 'cell_plate']
# [u'FSC-H', u'SSC-H', u'CD34 H : FITC H', u'CD14 H : PE H', u'BL3-H', u'BL4-H', u'CD66b H : CD3 H : PE-Cy7 H', u'Kit H : APC H', u'RL2-H', u'DAPI H', u'VL2-H', u'VL3-H', u'VL4-H', u'VL5-H', u'CD38 H : BV785 H', u'FSC-A', u'SSC-A', u'CD34 A : FITC A', u'CD14 A : PE A', u'BL3-A', u'BL4-A', u'CD66b A : CD3 A : PE-Cy7 A', u'Kit A : APC A', u'RL2-A', u'DAPI A', u'VL2-A', u'VL3-A', u'VL4-A', u'VL5-A', u'CD38 A : BV785 A', u'Width', u'Time', 'screen', 'well', 'cell_plate']
# [u'FSC-H', u'SSC-H', u'CD34 H : FITC H', u'Kit H : PE H', u'BL3-H', u'BL4-H', u'CD163 H : PE-Cy7 H', u'CD3 H : CD66b H : APC H', u'RL2-H', u'DAPI H', u'VL2-H', u'VL3-H', u'VL4-H', u'VL5-H', u'CD38 H : BV785 H', u'FSC-A', u'SSC-A', u'CD34 A : FITC A', u'Kit A : PE A', u'BL3-A', u'BL4-A', u'CD163 A : PE-Cy7 A', u'CD3 A : CD66b A : APC A', u'RL2-A', u'DAPI A', u'VL2-A', u'VL3-A', u'VL4-A', u'VL5-A', u'CD38 A : BV785 A', u'Width', u'Time', 'screen', 'well', 'cell_plate']

# %%
print(data[0].head(n=1))
print(data[1].head(n=1))
print(data[2].head(n=1))
# Out:
#        FSC-H       SSC-H  CD66B H : CD19 H : CD3 H : FITC H  CD14 H : PE H  \
# 0  8528540.0  16772247.0                             3821.0         4139.0
#
#     BL3-H  7AAD H    BL5-H  CD16 H : APC H    RL2-H  KIT H : BV421 H  \
# 0  5925.0  5029.0  16137.0          5158.0  17185.0           4635.0
#
#        ...          VL2-A    VL3-A  CD34 A : BV605 A    VL5-A     VL6-A  \
# 0      ...       316971.0 -12522.0          155582.0 -91590.0  945194.0
#
#     Width    Time      screen      well    cell_plate
# 0  5288.0  8377.0  screen_525  well_c03  cell_plate_1
#
# [1 rows x 35 columns]
#       FSC-A      FSC-H    SSC-A     SSC-H  CD66B A : CD19 A : CD3 A : FITC A  \
# 0  939045.0  1966693.0  99553.0  344426.0                            41750.0
#
#    CD66B H : CD19 H : CD3 H : FITC H  CD14 A : PE A  CD14 H : PE H   BL3-A  \
# 0                            34418.0       -21164.0         5334.0 -7524.0
#
#      BL3-H      ...       CD34 A : BV605 A  CD34 H : BV605 H    VL5-A  \
# 0  10667.0      ...               142439.0           80051.0  74544.0
#
#      VL5-H   VL6-A   VL6-H        Time      screen                    well  \
# 0  32057.0  1176.0  4579.0  89000952.0  screen_525  well_c03_cluster_blast
#
#      cell_plate
# 0  cell_plate_1
#
# [1 rows x 34 columns]
#       FSC-A      FSC-H    SSC-A     SSC-H  CD66B A : CD19 A : CD3 A : FITC A  \
# 0  719351.0  1649228.0  36465.0  177984.0                           947248.0
#
#    CD66B H : CD19 H : CD3 H : FITC H  CD14 A : PE A  CD14 H : PE H    BL3-A  \
# 0                           225735.0       -23230.0        14055.0 -13978.0
#
#     BL3-H      ...       CD34 A : BV605 A  CD34 H : BV605 H   VL5-A   VL5-H  \
# 0  3053.0      ...               308311.0           75986.0 -9208.0  8816.0
#
#    VL6-A   VL6-H        Time      screen                      well  \
# 0  -42.0  3648.0  89000952.0  screen_525  well_c03_cluster_healthy
#
#      cell_plate
# 0  cell_plate_1
#
# [1 rows x 34 columns]

# %%
# Check if individual datasets have duplicate values
idx = 0;
for temp in data:
    if temp.duplicated().sum() > 0:
        print("data number " + idx + "has duplicated rows")

# %% [markdown]
# #### Make a function to label the parent dataframe

# %%
def label_dup_rows_blast_only(parent_df, blast_child_df):
    '''
    parent and blast_child are pandas dataframes and should be entered in that order
    I have 3 dataframes  
    1) lets call it "parent_df" or "p1_df". It is ~10,000 rows and 30 columns
    3) "child1_df" or "f1_df". It is ~200 rows and 29 columns and is also a subset of "parent_df".
I want to identify which rows in "parent_df" match a row in "child1_df" (e.g. blast cells) and 
    then add a column to "parent_df" with a label of "child1".

To do this, 
    1) I add a "lineage" column with a value of either "parent" or "child1" to an entire dataframe.
    2) Also add a "cell_label" column with a value of "unlabelled" or "blast" 
    3) Concatenate "parent" to "child1" and then use duplicate to identify and label events in
        "parent" as "healthy", then drop "child1" from that dataframe
    '''
    # Label the lineage and cell type
    parent_df['cell_label'] = "unlabelled"
    parent_df['lineage'] = "parent"
    blast_child_df['cell_label'] = "blast"
    blast_child_df['lineage'] = "child1"

    # Select all columns that you expect to match when looking for duplicates
    cols_of_int = [x for x in list(parent_df.columns.values) if x not in ["Width","lineage","cell_label",\
                                                                          "screen","well","cell_plate","Time"]]
    #print(cols_of_int)
    
    ##### CHILD 1 = blast
    # Merge the parent to child1
    concat_pd = pd.concat([parent_df, blast_child_df], ignore_index = True)
        
    # Find all duplicated rows 
    dup_rows = concat_pd.duplicated(cols_of_int, keep = False)

    # Set the "cell_label" in duplicated rows = to the child1 label
    concat_pd.loc[dup_rows,"cell_label"] = "blast"

    # Now drop the child dataframe from the parent dataframe
    labelled_parent = concat_pd[concat_pd.lineage != "child1"]

    
    print("one1")
#    print(sum(dup_rows)/2)
    print("two2")
#    print(sum(dup_rows1)/2)
    print("three3")
    print(blast_child_df.shape)
#    print("four4")
#    print(healthy_child_df.shape)
    print("five5")
    print(parent_df.shape)
    
    
    return labelled_parent

# %%
labelled_test = label_dup_rows_blast_only(data[56],data[57])
labelled_test["cell_label"].value_counts()
# Out:
# one1
# two2
# three3
# (1339, 36)
# five5
# (29539, 37)
# unlabelled    28200
# blast          1339
# Name: cell_label, dtype: int64

# %%
type(labelled_test)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ##### Find all children files and match them to their parent

# %% [markdown]
# file_name is a list of all the csvs that I created and the pandasdataframe for each csv is in a list called data.
# so file_name[0] has the filename for the data in data[0].
#     1) Find all datasets that have been labelled for healthy and blast
#     2) Apply the above function ("label_dup_rows_blast_only") to label the parent dataframe (p1) for both "healthy" and "blast"
#     3) Output these labelled dataframes to csv files. Use extension "cell_populations_labelled_for_blast.csv"
#     4) Keep track of which p1s that I have labelled
#     5) Label the rest of the dataframes as "cell_pops_not_labelled" and output as csv files. use extension "cell_populations_NOT_labelled_for_blast.csv"

# %%
# Sanity check to make sure that file_name and data are what I think that they are
if not len(file_name) == len(data):
    print("Well this was unexpected, wires got crossed somewhere, please panic")

# %%
# Find all the data sets that have been labelled with healthy, use 
##  this to find the corresponding blast and parent dataset
#matches = [x for x in file_name if "blast" in x]
matches = [x for x in file_name if "blast" in x]
#print(matches)
print(type(matches[0].split('_')[:-2]))
print(matches[0].split('_')[:-2])
exp_base_name = "_".join(matches[0].split('_')[:-2])
print(exp_base_name)
# Out:
# <type 'list'>
# ['screen', '357', 'cell', 'plate', '1', 'labeled', 'merged', 'screen', '357', 'cell', 'plate', '1', 'labeled', 'merged', 'well', 'e19']
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e19

# %%
base_matches = [x for x in file_name if exp_base_name in x]
print(base_matches)
# Out:
# ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e19.csv', 'screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e19_cluster_blast.csv']

# %%
p1 = [x for x in base_matches if not "cluster" in x]

# %%
blast_child = [x for x in base_matches if "blast" in x]

# %%
print(base_matches)
print(blast_child[0])
print(type(blast_child[0]))
print(base_matches.index(blast_child[0]))
print(data[file_name.index(blast_child[0])].head(n=1))
# Out:
# ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e19.csv', 'screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e19_cluster_blast.csv']
# screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e19_cluster_blast.csv
# <type 'str'>
# 1
#       FSC-A      FSC-H  SSC-A     SSC-H  CD34 A : FITC A  CD34 H : FITC H  \
# 0  819775.0  1899994.0    0.0  332409.0          85873.0          44188.0
#
#    CD14 A : PE A  CD14 H : PE H    BL3-A   BL3-H   ...     VL5-A   VL5-H  \
# 0        16378.0        10078.0  12365.0  8394.0   ...       0.0  2415.0
#
#    CD38 A : BV785 A  CD38 H : BV785 H          Time  \
# 0               0.0            3675.0  1.477981e+09
#
#                                    screen                    well  \
# 0  screen_357_cell_plate_1_labeled_merged  well_e19_cluster_blast
#
#                                cell_plate  cell_label  lineage
# 0  screen_357_cell_plate_1_labeled_merged       blast   child1
#
# [1 rows x 36 columns]

# %% [markdown]
# ### OK, put it all together now to label a bunch of files

# %%
matches = [x for x in file_name if "blast" in x] # Find all files with the word healthy 
## in them (indicating that they are a subset of events that Diane classified as healthy)
labelled_pds_dfs = []; which_pds_dfs_got_lab = [] # This is a list of indexes so that I don't overwrite them later...not implemented
for idx, match in enumerate(matches):
    p1_data_loc = None; blast_data_loc = None; healthy_data_loc = None;
    exp_base_name = "_".join(matches[idx].split('_')[:-2])
    base_matches = [x for x in file_name if exp_base_name in x]
    p1 = [x for x in base_matches if not "cluster" in x]
    blast_child = [x for x in base_matches if "blast" in x]
    print("Identified" + str(p1) + "as the parent of blast file: " + str(blast_child))
    print("Labelling the parent now with which rows correspond to each child")
    p1_data_loc = file_name.index(p1[0])
    blast_data_loc = file_name.index(blast_child[0])
    # Below input to function should be in the order: parent, healthy, blast
    labelled_pds_dfs.append(label_dup_rows_blast_only(data[p1_data_loc],data[blast_data_loc]))
    # Write out the labelled file
    labelled_pds_dfs[idx].to_csv(directory + '/' + "LABELLED_by_cell_type_" + file_name[p1_data_loc])
# Out:
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e19.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e19_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1339, 36)
# five5
# (29539, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e21.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_e21_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1649, 36)
# five5
# (27776, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f03.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f03_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (946, 36)
# five5
# (25787, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f05.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f05_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1797, 36)
# five5
# (26273, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f07.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f07_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1490, 36)
# five5
# (26544, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f09.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f09_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1220, 36)
# five5
# (24209, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f11.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f11_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1310, 36)
# five5
# (24674, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f13.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f13_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1915, 36)
# five5
# (28427, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f15.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f15_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1703, 36)
# five5
# (27651, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f17.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f17_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1604, 36)
# five5
# (27134, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f21.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_f21_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1607, 36)
# five5
# (27291, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g03.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g03_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (3427, 36)
# five5
# (27938, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g05.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g05_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (5773, 36)
# five5
# (29035, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g07.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g07_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1890, 36)
# five5
# (28080, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g09.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g09_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (4633, 36)
# five5
# (26955, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g11.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g11_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (3642, 36)
# five5
# (25483, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g13.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g13_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1400, 36)
# five5
# (17459, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g15.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g15_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (5227, 36)
# five5
# (29824, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g17.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g17_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (3551, 36)
# five5
# (28638, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g19.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g19_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (5786, 36)
# five5
# (29124, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g21.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_g21_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (5875, 36)
# five5
# (28987, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h03.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h03_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (6227, 36)
# five5
# (25367, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h05.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h05_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (4441, 36)
# five5
# (27989, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h07.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h07_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (3289, 36)
# five5
# (28883, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h09.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h09_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (6060, 36)
# five5
# (27505, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h11.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h11_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (6069, 36)
# five5
# (29380, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h13.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h13_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (6695, 36)
# five5
# (31364, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h15.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h15_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (6876, 36)
# five5
# (33147, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h17.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h17_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (6291, 36)
# five5
# (31560, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h19.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h19_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (4959, 36)
# five5
# (33928, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h21.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_h21_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (5334, 36)
# five5
# (32476, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i03.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i03_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (5245, 36)
# five5
# (28826, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i05.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i05_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (2429, 36)
# five5
# (27681, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i07.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i07_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (6024, 36)
# five5
# (25105, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i09.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i09_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (3214, 36)
# five5
# (21866, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i11.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i11_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (5341, 36)
# five5
# (25622, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i13.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i13_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (2651, 36)
# five5
# (37715, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i15.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i15_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (6611, 36)
# five5
# (32006, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i17.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i17_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (6216, 36)
# five5
# (29897, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i19.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i19_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (6741, 36)
# five5
# (27542, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i21.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_i21_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (3666, 36)
# five5
# (32077, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j03.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j03_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (4877, 36)
# five5
# (24672, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j05.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j05_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (6275, 36)
# five5
# (31273, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j07.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j07_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (4275, 36)
# five5
# (22476, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j09.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j09_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (4278, 36)
# five5
# (22637, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j11.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j11_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (4781, 36)
# five5
# (25295, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j13.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j13_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (2177, 36)
# five5
# (33824, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j15.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j15_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (4416, 36)
# five5
# (22548, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j17.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j17_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (5298, 36)
# five5
# (28554, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j19.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j19_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (6041, 36)
# five5
# (24914, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j21.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_j21_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (6543, 36)
# five5
# (27332, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k03.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k03_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (2879, 36)
# five5
# (24584, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k05.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k05_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (3125, 36)
# five5
# (29204, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k07.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k07_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (2431, 36)
# five5
# (21735, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k09.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k09_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1889, 36)
# five5
# (28021, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k11.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k11_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1606, 36)
# five5
# (24818, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k13.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k13_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (788, 36)
# five5
# (18979, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k15.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k15_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1001, 36)
# five5
# (30324, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k19.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k19_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1717, 36)
# five5
# (18224, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k21.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_k21_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (2312, 36)
# five5
# (21079, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l03.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l03_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (4286, 36)
# five5
# (28207, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l05.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l05_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (2686, 36)
# five5
# (28024, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l07.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l07_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1531, 36)
# five5
# (16831, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l09.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l09_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1596, 36)
# five5
# (19288, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l11.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l11_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1749, 36)
# five5
# (22862, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l13.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l13_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (2833, 36)
# five5
# (26955, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l15.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l15_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (2776, 36)
# five5
# (23534, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l17.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l17_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (2673, 36)
# five5
# (25028, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l19.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l19_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1562, 36)
# five5
# (18836, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l21.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_l21_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1899, 36)
# five5
# (18980, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m03.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m03_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (9688, 36)
# five5
# (28431, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m05.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m05_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (725, 36)
# five5
# (35615, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m07.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m07_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (5895, 36)
# five5
# (26353, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m09.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m09_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (3206, 36)
# five5
# (16649, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m13.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m13_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (828, 36)
# five5
# (20604, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m15.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m15_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (4875, 36)
# five5
# (22649, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m17.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m17_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1754, 36)
# five5
# (19994, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m19.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m19_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (721, 36)
# five5
# (15903, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m21.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_m21_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1149, 36)
# five5
# (19058, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n03.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n03_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (3074, 36)
# five5
# (30844, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n05.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n05_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (769, 36)
# five5
# (28381, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n07.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n07_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1017, 36)
# five5
# (16179, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n09.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n09_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1066, 36)
# five5
# (14387, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n11.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n11_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (1050, 36)
# five5
# (11843, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n13.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n13_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (556, 36)
# five5
# (19071, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n16.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n16_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (3874, 36)
# five5
# (17813, 37)
# Identified['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n22.csv']as the parent of blast file: ['screen_357_cell_plate_1_labeled_merged_screen_357_cell_plate_1_labeled_merged_well_n22_cluster_blast.csv']
# Labelling the parent now with which rows correspond to each child
# one1
# two2
# three3
# (12, 36)
# five5
# (12680, 37)

# %%
print(len(labelled_pds_dfs))
print(type(labelled_pds_dfs))
print(len(file_name))
print(len(matches))

print(type(labelled_pds_dfs[0]))
#bobbb = labelled_pds_dfs[0]
print(labelled_pds_dfs[2]["cell_label"].value_counts())
# Out:
# 87
# <type 'list'>
# 327
# 87
# <class 'pandas.core.frame.DataFrame'>
# unlabelled    24841
# blast           946
# Name: cell_label, dtype: int64

# %% [markdown]
# #### Write the labelled data to file

# %%
for lab_file in labelled_pds_dfs:
    print("Save file " + file_name[idx])
    lab_file.to_csv(directory + '/' + file_name[idx])
